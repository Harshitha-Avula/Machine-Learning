# %% [markdown]
# Draw a line using given axis values with suitable label in the x axis , y axis and a title.
# <pre>
# # x axis values
# x = [1,2,3]
# # y axis values
# y = [2,4,1]
# </pre>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#x axis values
x = [1,2,3]
# y axis values
y = [2,4,1]
plt.plot(x,y, marker = '^', color = 'c')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Line Plot")
# Out:
# Text(0.5, 1.0, 'Line Plot')

# %% [markdown]
# Plot two or more lines with  different widths and colors.
# Plot two or more lines with different linestyles.
# Plot two or more lines and set the line markers of your choice

# %%
plt.plot(x,y, linewidth=3.5, linestyle='--',marker = "o", markeredgecolor='k', markerfacecolor='r', label = '(x,y)' )
plt.plot(x,x, linewidth=3, linestyle=':', marker = '*', label = '(x,x)')

plt.legend()

# %% [markdown]
# - Plot the data with given x and y values.
# - Display only a part of it using xlim and ylim

# %%
line, = plt.plot(x, y, '-')
line.set_antialiased(False)
plt.xlim(1, 3)
plt.ylim(2,5)
# Out:
# (2, 5)

# %% [markdown]
# Plot several lines with different format styles in one command using arrays.Use the plot function only once

# %%
x = np.arange(2,25,3.2)
y = np.arange(1,25,3.2)
#labels = ['(x,y)', '(x,y**2)','x**2 +3*x+2' , 'y**2']
plt.plot(x,y,'b1-', x, y**2, 'g>-', x**2 +3*x+2, 'cX:', y**2, 'kD--')
# Out:
# [<matplotlib.lines.Line2D at 0x26fa5577128>,
#  <matplotlib.lines.Line2D at 0x26fa5577240>,
#  <matplotlib.lines.Line2D at 0x26fa5577588>,
#  <matplotlib.lines.Line2D at 0x26fa55778d0>]

# %% [markdown]
# Display a bar chart of the popularity of programming Languages. <br>
# Sample data:<br>
# Programming languages: Java, Python, PHP, JavaScript, C#, C++<br>
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7<br>

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6,8.8,8,7.7, 6.7]
plt.bar(languages, popularity, width = 0.9, edgecolor = 'k', linestyle = '-.', color = 'c' )
# Out:
# <BarContainer object of 6 artists>

# %%
plt.barh(languages, popularity, edgecolor = 'k', linestyle = '-.', color = 'c',  orientation = 'horizontal')
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# Display a bar chart of the popularity of programming Languages. Use different color for each bar

# %%
plt.bar(languages, popularity, color = 'bckymg',  edgecolor = 'k', linestyle = '-.' )
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# For the above data create a pie chart

# %%
colors = ['magenta', 'gold', 'lightcoral', 'lightskyblue', 'yellowgreen', 'cyan']

plt.pie(popularity,explode = (0.06, 0,0,0, 0, 0), autopct = '%0.01f%%', shadow = True, colors = colors)

plt.tight_layout()
plt.legend(languages, bbox_to_anchor=(1, 1.05))

# %% [markdown]
# For the above data create a pie chart mention your choice of colors with hexadecimal values

# %%
from matplotlib import cm
colors = ['#123456']
#cs=cm.Set1(np.arange(6))
colors = ['#1100de','#a12b3c','#012e3d','#ffcc99', '#11dd11', '#dd1122']

plt.pie(popularity,explode = (0.06, 0,0,0, 0, 0), autopct = '%0.01f%%', shadow = True, colors = colors)

plt.tight_layout()
plt.legend(languages, bbox_to_anchor=(1, 1.05))

# %% [markdown]
# Draw a scatter plot  taking a random distribution in X and Y and plotted against each other<br>
# use random.randn function

# %%
x =np.random.randn(5,10)
y = np.random.randn(5,10)
plt.scatter(x,y, edgecolor = 'k', marker = 'X', cmap = 'twilight')

# %% [markdown]
# Draw a scatter plot with empty circles taking a random distribution in X and Y and plotted against each other<br>
# use random.randn function

# %%
x = np.random.randn(100)
y = np.random.randn(100)
plt.scatter(x, y, color = 'gray', facecolors = 'none', s= 50)

# %% [markdown]
# draw a scatter plot using random distributions to generate circles of different sizes.

# %%
x = np.random.randn(100)
y = np.random.rand(100)
colors = np.random.randn(100)
sizes = np.random.rand(100)
plt.scatter(x,y, c = colors, s = 100 * sizes, cmap = 'viridis', alpha = 0.5)
plt.colorbar()

# %% [markdown]
# draw a histogram owith your choice of data generated with numpy

# %%
plt.figure(figsize=[10,8])

x = np.random.randn(1000)

plt.hist(x, bins = 5)
plt.grid(axis = 'y', alpha = 0.4)
plt.xlabel('Value',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.title('Histogram',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
plt.figure(figsize=[10,8])

x = 0.3*np.random.randn(100)
y = 0.3*np.random.randn(50)

plt.hist([x,y], label = ['x', 'y'])
plt.grid(axis = 'y', alpha = 0.4)
plt.xlabel('Value',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.title('Histogram',fontsize=15)
plt.legend()
